# %% [markdown]
# <a href="https://colab.research.google.com/github/njasharp/python-source-code/blob/main/heatmap_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ** new text**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = np.random.rand(10, 12)
df = pd.DataFrame(data, columns=[f'Col{i}' for i in range(1, 13)])

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df, annot=True, cmap='coolwarm')
plt.title('Heat Map Example')
plt.show()

# %%
plt.figure(figsize=(5, 4))
sns.heatmap(df, annot=True, cmap='coolwarm')
plt.title('Heat Map Example')
plt.show()
